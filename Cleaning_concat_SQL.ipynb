# %%
import pandas as pd

# %%
nazare = pd.read_csv (r'firstdf.csv')
pipeline = pd.read_csv (r'pipedf.csv')
mundaka = pd.read_csv (r'mundaka_correct_df.csv')
fronton = pd.read_csv (r'fronton.csv')
box = pd.read_csv (r'firstdf.csv')
puerto_escondido = pd.read_csv (r'puerto_escondido.csv')
itacoatiara = pd.read_csv (r'itacoatiara.csv')
padang_padang = pd.read_csv (r'padang-padang.csv')
kirra = pd.read_csv (r'kirra.csv')
mosca = pd.read_csv (r'mosca.csv')
tauro = pd.read_csv (r'tauro.csv')

# %% [markdown]
# ### Creating lists

# %%
nazare_ = ["Nazare"]
pipeline_ = ["Pipeline"]
mundaka_ = ["Mundaka"]
fronton_ = ["Fronton"]
box_ = ["The Box"]
puerto_escondido_ = ["Puerto Escondido"]
itacoatiara_ =  ["Itacoatiara"]
padang_padang_ =  ["Padang-Padang"]
kirra_ = ["Kirra"]
mosca_ = ["Mosca Point"]
tauro_ = ["Tauro"]

# %%
list_nazare = nazare_ * nazare.shape[0]

list_pipeline = pipeline_ * nazare.shape[0]

list_mundaka = mundaka_ * nazare.shape[0]

list_fronton = fronton_ * nazare.shape[0]

list_box = box_ * nazare.shape[0]

list_puerto_escondido = puerto_escondido_ * nazare.shape[0]

list_itacoatiara = itacoatiara_ * nazare.shape[0]

list_padang_padang = padang_padang_ * nazare.shape[0]

list_mosca = mosca_ * mosca.shape[0]

list_tauro = tauro_ * tauro.shape[0]

# %% [markdown]
# ### Inserting new columns (quality,name)

# %% [markdown]
# #### Nazare

# %%
nazare.shape
# Out:
# (1098, 15)

# %%
nazare.head()
# Out:
#     date  time   range height period  wind_mph  wind_kmh  mph  temp  prob  \
# 0  01/01   6am  7-11ft    5ft    11s         3         4  mph   6°c  100%
# 1  01/01  12pm  7-11ft    5ft    10s         4         6  mph  13°c  100%
# 2  01/01   6pm  6-10ft  4.5ft    10s         1         1  mph   8°c  100%
# 3  02/01   6am   4-7ft  2.5ft    10s         5         6  mph   6°c  100%
# 4  02/01  12pm   5-8ft    3ft    12s         6         9  mph  11°c  100%
#
#   swell_dir  swell_angle      wind wind_dir  wind_angle    Spot Conditions
# 0        NW          306  Offshore      ESE         115  Nazare       Good
# 1        NW          310  Offshore       SE         144  Nazare       Good
# 2        NW          309  Offshore        S         171  Nazare       Good
# 3        NW          322  Offshore       SE         129  Nazare       Good
# 4         W          276  Offshore      SSE         156  Nazare       Good

# %%
nazare['Spot'] = list_nazare

# %%
def apply_condi_naz(string):
    if int(string[3:5]) in ([10,11,3]) :
        return "Epic"
    elif int(string[3:5]) in([9,12,1,2]):
        return "Good"
    elif int(string[3:5]) in ([4]):
        return "Mediocre"
    else:
        return "Not recommended"

# %%
nazare['Conditions'] = nazare.date.apply(apply_condi_naz)

# %% [markdown]
# ####  Pipeline

# %%
pipeline.head()
# Out:
#     date  time   range height period  wind_mph  wind_kmh  mph  temp  prob  \
# 0  01/01   6am  7-11ft  7.5ft    16s        17        20  mph  23°c  100%
# 1  01/01  12pm  6-10ft    7ft    15s        12        13  mph  24°c  100%
# 2  01/01   6pm  6-10ft    7ft    15s         9        10  mph  24°c  100%
# 3  02/01   6am   5-8ft    6ft    14s         7         8  mph  23°c  100%
# 4  02/01  12pm   5-8ft  5.5ft    13s        10        11  mph  24°c  100%
#
#   swell_dir  swell_angle            wind wind_dir  wind_angle      Spot  \
# 0        NW          312        Offshore      ESE         108  Pipeline
# 1        NW          312  Cross/Offshore        E          82  Pipeline
# 2        NW          314         Onshore       NE          35  Pipeline
# 3        NW          313         Onshore      NNE          32  Pipeline
# 4        NW          314   Cross/Onshore       NE          46  Pipeline
#
#   Conditions
# 0       Epic
# 1       Epic
# 2       Epic
# 3       Epic
# 4       Epic

# %%
pipeline['Spot'] = list_pipeline

# %%
def apply_condi_pip(string):
    if int(string[3:5]) in ([11,12,1,2]) :
        return "Epic"
    elif int(string[3:5]) in([10,3]):
        return "Good"
    elif int(string[3:5]) in ([9]):
        return "Mediocre"
    else:
        return "Not recommended"

# %%
pipeline['Conditions'] = pipeline.date.apply(apply_condi_pip)

# %% [markdown]
# #### Mundaka

# %%
mundaka.head()
# Out:
#       Spot   date  time  range height swell_dir  swell_angle period  wind_kmh  \
# 0  Mundaka  01/01   6am  3-4ft    4ft       WNW          304    12s         6
# 1  Mundaka  01/01  12pm  3-4ft  4.5ft        NW          305    11s         6
# 2  Mundaka  01/01   6pm  3-4ft  4.5ft        NW          307    11s         6
# 3  Mundaka  02/01   6am  2-3ft    3ft        NW          311    10s         8
# 4  Mundaka  02/01  12pm  2-3ft  2.5ft        NW          312    10s         9
#
#   wind_dir      wind  wind_angle  temp Conditions
# 0       SW  Offshore         220  10°c       Epic
# 1      SSW  Offshore         194  11°c       Epic
# 2        E   Onshore          91  12°c       Epic
# 3      SSE  Offshore         149  10°c       Epic
# 4        S  Offshore         183  11°c       Epic

# %%
mundaka['Spot'] = list_mundaka

# %%
def apply_condi_mun(string):
    if int(string[3:5]) in ([12,1]) :
        return "Epic"
    elif int(string[3:5]) in([10,11,2,3]):
        return "Good"
    elif int(string[3:5]) in ([9]):
        return "Mediocre"
    else:
        return "Not recommended"

# %%
mundaka['Conditions'] = mundaka.date.apply(apply_condi_mun)

# %%
mundaka = mundaka[['Spot', 'date', 'time', 'range', "height","swell_dir", "swell_angle","period","wind_kmh","wind_dir","wind","wind_angle","temp","Conditions"]]

# %% [markdown]
# #### Fronton

# %%
fronton.sample()
# Out:
#        date  time  range height period  wind_mph  wind_kmh  mph  temp prob  \
# 1072  23/12  12pm  3-5ft    5ft    13s        21        23  mph  20°c  NaN
#
#      swell_dir  swell_angle      wind wind_dir  wind_angle     Spot Conditions
# 1072        NW          311  Offshore       SE         139  Fronton       Epic

# %%
fronton['Spot'] = list_fronton

# %%
def apply_condi_fron(string):
    if int(string[3:5]) in ([10,11,12,1]) :
        return "Epic"
    elif int(string[3:5]) in([2,3]):
        return "Good"
    elif int(string[3:5]) in ([9]):
        return "Mediocre"
    else:
        return "Not recommended"

# %%
fronton['Conditions'] = fronton.date.apply(apply_condi_fron)

# %% [markdown]
# #### Box

# %%
box.sample()
# Out:
#       date  time  range height period  wind_mph  wind_kmh  mph  temp prob  \
# 820  30/09  12pm  4-6ft  2.5ft    11s        12        17  mph  20°c  NaN
#
#     swell_dir  swell_angle     wind wind_dir  wind_angle     Spot Conditions
# 820        NW          309  Onshore      NNW         339  The Box       Epic

# %%
box['Spot'] = list_box

# %%
def apply_condi_box(string):
    if int(string[3:5]) in ([6,7,8,9]) :
        return "Epic"
    elif int(string[3:5]) in([1,2,3,4,5,10,11,12]):
        return "Good"

# %%
box['Conditions'] = box.date.apply(apply_condi_box)

# %% [markdown]
# #### Puerto escondido

# %%
puerto_escondido.sample(10)
# Out:
#       date  time   range height period  wind_mph  wind_kmh  mph  temp  prob  \
# 892  24/10  12pm   5-8ft  3.5ft    12s         4         4  mph  29°c   NaN
# 467  04/06   6pm  8-12ft    5ft    16s        11        13  mph  28°c  100%
# 935  07/11   6pm  7-11ft    5ft    14s         3         4  mph  27°c   NaN
# 381  07/05   6am   5-8ft  3.5ft    14s         5         6  mph  27°c  100%
# 452  30/05   6pm  6-10ft  3.5ft    19s        10        11  mph  28°c  100%
# 31   11/01  12pm   2-3ft    1ft    16s         8         7  mph  28°c  100%
# 709  24/08  12pm   5-8ft  4.5ft     9s         6         6  mph  27°c  100%
# 716  26/08   6pm   5-8ft  6.5ft     9s        15        17  mph  27°c  100%
# 127  12/02  12pm   6-9ft  3.5ft    16s         9         5  mph  30°c  100%
# 88   30/01  12pm   4-6ft    2ft    19s         7         6  mph  27°c  100%
#
#     swell_dir  swell_angle            wind wind_dir  wind_angle  \
# 892       SSW          192         Onshore      SSW         198
# 467        SW          214         Onshore        W         260
# 935       SSW          208         Onshore        W         259
# 381       SSW          205  Cross/Offshore      WNW         304
# 452       SSW          211         Onshore        W         260
# 31         SW          217         Onshore      SSE         151
# 709         S          184         Onshore      SSE         157
# 716         W          259         Onshore      WSW         259
# 127       SSW          205         Onshore       SW         219
# 88        SSW          200         Onshore      SSW         205
#
#                  Spot       Conditions
# 892  Puerto Escondido         Mediocre
# 467  Puerto Escondido             Epic
# 935  Puerto Escondido  Not recommended
# 381  Puerto Escondido             Epic
# 452  Puerto Escondido             Epic
# 31   Puerto Escondido  Not recommended
# 709  Puerto Escondido             Good
# 716  Puerto Escondido             Good
# 127  Puerto Escondido         Mediocre
# 88   Puerto Escondido  Not recommended

# %%
def apply_condi_pe(string):
    if int(string[3:5]) in ([4,5,6]) :
        return "Epic"
    elif int(string[3:5]) in([7,8,9]):
        return "Good"
    elif int(string[3:5]) in ([2,3,10]):
        return "Mediocre"
    else:
        return "Not recommended"

# %%
puerto_escondido['Conditions'] = puerto_escondido.date.apply(apply_condi_pe)

# %% [markdown]
# #### Itacoatiara

# %%
itacoatiara.head()
# Out:
#     date  time range height period  wind_mph  wind_kmh  mph  temp  prob  \
# 0  01/01   6am   1ft    3ft     8s         7         9  mph  24°c  100%
# 1  01/01  12pm   1ft    3ft     7s        10        11  mph  28°c  100%
# 2  01/01   6pm   1ft    3ft     7s        13        16  mph  28°c  100%
# 3  02/01   6am   1ft    3ft     7s         6         7  mph  25°c  100%
# 4  02/01  12pm   1ft  2.5ft     7s        11        12  mph  25°c  100%
#
#   swell_dir  swell_angle            wind wind_dir  wind_angle         Spot  \
# 0         E           99        Offshore      NNE          20  Itacoatiara
# 1         E           98     Cross-shore        E          98  Itacoatiara
# 2         E           97  Cross/Offshore        E          84  Itacoatiara
# 3         E           97   Cross/Onshore      WSW         254  Itacoatiara
# 4         E           99         Onshore        S         187  Itacoatiara
#
#         Conditions
# 0  Not recommended
# 1  Not recommended
# 2  Not recommended
# 3  Not recommended
# 4  Not recommended

# %%
itacoatiara['Spot'] = list_itacoatiara

# %%
def apply_condi_ita(string):
    if int(string[3:5]) in ([6,7]) :
        return "Epic"
    elif int(string[3:5]) in([5,8,9]):
        return "Good"
    elif int(string[3:5]) in ([4]):
        return "Mediocre"
    else:
        return "Not recommended"

# %%
itacoatiara['Conditions'] = itacoatiara.date.apply(apply_condi_ita)

# %% [markdown]
# #### Padang-padang

# %%
padang_padang.head()
# Out:
#     date  time  range height period  wind_mph  wind_kmh  mph  temp  prob  \
# 0  01/01   6am  Plano    7ft    14s         6         6  mph  28°c  100%
# 1  01/01  12pm  Plano    7ft    15s        14        14  mph  28°c  100%
# 2  01/01   6pm  Plano    7ft    14s         7         8  mph  27°c  100%
# 3  02/01   6am  Plano  6.5ft    14s         7         6  mph  27°c  100%
# 4  02/01  12pm  Plano    6ft    13s         9        10  mph  29°c  100%
#
#   swell_dir  swell_angle            wind wind_dir  wind_angle           Spot  \
# 0       SSW          207         Onshore      WNW         284  Padang-Padang
# 1       SSW          206  Cross/Offshore       NW         323  Padang-Padang
# 2       SSW          207  Cross/Offshore       NW         316  Padang-Padang
# 3       SSW          207        Offshore      NNE          19  Padang-Padang
# 4       SSW          208         Onshore      WSW         252  Padang-Padang
#
#   Conditions
# 0   Mediocre
# 1   Mediocre
# 2   Mediocre
# 3   Mediocre
# 4   Mediocre

# %%
padang_padang['Spot'] = list_padang_padang

# %%
def apply_condi_pp(string):
    if int(string[3:5]) in ([6,7,8]) :
        return "Epic"
    elif int(string[3:5]) in([5,10,9]):
        return "Good"
    elif int(string[3:5]) in ([1,2,3,4,11,12]):
        return "Mediocre"

# %%
padang_padang['Conditions'] = padang_padang.date.apply(apply_condi_pp)

# %% [markdown]
# #### Kirra

# %%
kirra.sample()
# Out:
#       date  time  range height period  wind_mph  wind_kmh  mph  temp prob  \
# 976  21/11  12pm  2-4ft  3.5ft     7s         8         8  mph  26°c  NaN
#
#     swell_dir  swell_angle     wind wind_dir  wind_angle   Spot  \
# 976         E           83  Onshore       NE          41  Kirra
#
#           Conditions
# 976  Not recommended

# %%
kirra['Spot'] = list_kirra

# %%
def apply_condi_kir(string):
    if int(string[3:5]) in ([3,4,5]) :
        return "Epic"
    elif int(string[3:5]) in([2,6,7]):
        return "Good"
    else:
        return "Not recommended"

# %%
kirra['Conditions'] = kirra.date.apply(apply_condi_kir)

# %% [markdown]
# #### Mosca

# %%
mosca.head()
# Out:
#           Spot   date  time  range height swell_dir  swell_angle period  \
# 0  Mosca Point  01/01   6am    1ft  1.4ft       NNE           31     7s
# 1  Mosca Point  01/01  12pm  1-2ft    2ft       ESE          121     4s
# 2  Mosca Point  01/01   6pm  1-2ft  2.5ft       ESE          122     5s
# 3  Mosca Point  02/01   6am  1-2ft    2ft       ESE          113     5s
# 4  Mosca Point  02/01  12pm  1-2ft  2.5ft       ESE          111     5s
#
#    wind_kmh wind_dir           wind  wind_angle  temp Conditions
# 0        11      SSE  Cross/Onshore         163  12°c       Epic
# 1        14       SE        Onshore         137  16°c       Epic
# 2         9       SE        Onshore         136  14°c       Epic
# 3        12      SSE        Onshore         151  11°c       Epic
# 4        13       SE        Onshore         126  15°c       Epic

# %%
mosca['Spot'] = list_mosca

# %%
def apply_condi_mosca(string):
    if int(string[3:5]) in ([11,12,1,2]) :
        return "Epic"
    elif int(string[3:5]) in([3,9,10]):
        return "Good"
    elif int(string[3:5]) in([6,7,8]):
        return "Choppy"
    else:
        return "Not recommended"

# %%
mosca['Conditions'] = mosca.date.apply(apply_condi_mosca)

# %%
mosca = mosca[['Spot', 'date', 'time', 'range', "height","swell_dir", "swell_angle","period","wind_kmh","wind_dir","wind","wind_angle","temp","Conditions"]]

# %% [markdown]
# ### Tauro

# %%
tauro.head()
# Out:
#     Spot   date  time  range height swell_dir  swell_angle period  wind_kmh  \
# 0  Tauro  01/01   6am    1ft  0.8ft         W          279     9s        11
# 1  Tauro  01/01  12pm  0-1ft  0.6ft         W          279     8s        14
# 2  Tauro  01/01   6pm  0-1ft  0.6ft       WNW          284    10s         9
# 3  Tauro  02/01   6am  0-1ft  0.5ft       WNW          298    12s        12
# 4  Tauro  02/01  12pm    1ft  0.7ft       WNW          293    12s        13
#
#   wind_dir            wind  wind_angle  temp Conditions
# 0      SSE         Onshore         163  12°c       Epic
# 1       SE     Cross-shore         137  16°c       Epic
# 2       SE     Cross-shore         136  14°c       Epic
# 3      SSE   Cross/Onshore         151  11°c       Epic
# 4       SE  Cross/Offshore         126  15°c       Epic

# %%
tauro['Spot'] = list_tauro

# %%
def apply_condi_tauro(string):
    if int(string[3:5]) in ([11,12,1,2]) :
        return "Epic"
    elif int(string[3:5]) in([3,9,10]):
        return "Good"
    else:
        return "Not recommended"

# %%
tauro['Conditions'] = tauro.date.apply(apply_condi_tauro)

# %%
tauro = tauro[['Spot', 'date', 'time', 'range', "height","swell_dir", "swell_angle","period","wind_kmh","wind_dir","wind","wind_angle","temp","Conditions"]]

# %% [markdown]
# ### Concat dataframes into one

# %%
full = pd.concat([nazare ,pipeline , fronton ,box,puerto_escondido ,itacoatiara ,padang_padang], ignore_index=True)

# %%
full.head()
# Out:
#     date  time   range height period  wind_mph  wind_kmh  mph  temp  prob  \
# 0  01/01   6am  7-11ft    5ft    11s         3         4  mph   6°c  100%
# 1  01/01  12pm  7-11ft    5ft    10s         4         6  mph  13°c  100%
# 2  01/01   6pm  6-10ft  4.5ft    10s         1         1  mph   8°c  100%
# 3  02/01   6am   4-7ft  2.5ft    10s         5         6  mph   6°c  100%
# 4  02/01  12pm   5-8ft    3ft    12s         6         9  mph  11°c  100%
#
#   swell_dir  swell_angle      wind wind_dir  wind_angle
# 0        NW          306  Offshore      ESE         115
# 1        NW          310  Offshore       SE         144
# 2        NW          309  Offshore        S         171
# 3        NW          322  Offshore       SE         129
# 4         W          276  Offshore      SSE         156

# %%
full = pd.concat([full,kirra], ignore_index=True)

# %%
full.shape
# Out:
# (8784, 15)

# %%
full.drop(["mph","prob", "wind_mph"], axis = 1, inplace = True)

# %%
full = full[['Spot', 'date', 'time', 'range', "height","swell_dir", "swell_angle","period","wind_kmh","wind_dir","wind","wind_angle","temp","Conditions"]]

# %%
full.sample(20)
# Out:
#                    Spot   date  time    range height swell_dir  swell_angle  \
# 9346        Mosca Point  06/07  12pm    1-2ft    4ft         N            8
# 7929            Mundaka  22/03   6am    1-2ft  1.6ft        NW          313
# 4709   Puerto Escondido  15/04   6pm    6-9ft  4.5ft       SSW          197
# 3116            Fronton  02/11   6pm    3-4ft    3ft       NNW          337
# 4617   Puerto Escondido  16/03   6am   7-12ft    5ft       SSW          199
# 2825            Fronton  28/07   6pm    3-5ft  4.5ft       NNE           17
# 854              Nazare  11/10   6pm   7-12ft    7ft       NNW          336
# 5266   Puerto Escondido  18/10  12pm    6-9ft    4ft       SSW          210
# 6276        Itacoatiara  19/09   6am    2-3ft  1.8ft       SSW          192
# 7551      Padang-Padang  17/11   6am    5-7ft  5.5ft        SW          216
# 7169      Padang-Padang  12/07   6pm    Plano    8ft        SW          225
# 7018      Padang-Padang  23/05  12pm    Plano  1.9ft       SSW          204
# 3799            The Box  17/06  12pm    3-5ft  2.5ft       NNW          329
# 10586             Tauro  22/08   6pm      1ft  0.5ft       SSW          204
# 6480        Itacoatiara  26/11   6am    1-2ft    1ft       SSW          193
# 10146             Tauro  29/03   6am      1ft  0.6ft       SSW          201
# 4360            The Box  21/12  12pm  10-16ft    7ft       WNW          295
# 10094             Tauro  11/03   6pm      1ft  1.2ft       WNW          300
# 3553            The Box  27/03  12pm  12-18ft    8ft        NW          313
# 3654            The Box  30/04   6am  10-16ft    8ft       WNW          294
#
#       period  wind_kmh wind_dir            wind  wind_angle  temp  \
# 9346      8s        11        N     Cross-shore           3  28°c
# 7929     10s        13      WSW        Offshore         259  12°c
# 4709     13s         5      WSW         Onshore         250  27°c
# 3116     13s        15      NNE         Onshore          27  21°c
# 4617     18s         4       NE        Offshore          51  25°c
# 2825      7s        18        N         Onshore           9  22°c
# 854       9s        23        N         Onshore         359  18°c
# 5266     15s         6        S         Onshore         177  29°c
# 6276     16s         4      WSW         Onshore         244  23°c
# 7551     13s         8      ESE  Cross/Offshore         124  28°c
# 7169     19s        16      ESE  Cross/Offshore         109  26°c
# 7018     14s        11      WSW         Onshore         258  29°c
# 3799      8s        11       NW         Onshore         324  19°c
# 10586    12s        17        N        Offshore         356  27°c
# 6480     11s         9      NNE        Offshore          26  22°c
# 10146    14s         5        N        Offshore         357  12°c
# 4360     12s         9       SE        Offshore         145  14°c
# 10094    16s         4      ENE        Offshore          73  21°c
# 3553     13s         5      WSW         Onshore         251  16°c
# 3654     11s        13      WSW         Onshore         246  12°c
#
#             Conditions
# 9346            Choppy
# 7929              Good
# 4709              Epic
# 3116              Epic
# 4617          Mediocre
# 2825   Not recommended
# 854               Epic
# 5266          Mediocre
# 6276              Good
# 7551          Mediocre
# 7169              Epic
# 7018              Good
# 3799              Epic
# 10586  Not recommended
# 6480   Not recommended
# 10146             Good
# 4360              Good
# 10094             Good
# 3553              Good
# 3654              Good

# %%
full.to_csv("Full_clean_df.csv", index=False)

# %% [markdown]
# ### Changing data types

# %%
full.dtypes
# Out:
# Spot           object
# date           object
# time           object
# range          object
# height         object
# swell_dir      object
# swell_angle     int64
# period         object
# wind_kmh        int64
# wind_dir       object
# wind           object
# wind_angle      int64
# temp           object
# Conditions     object
# dtype: object

# %%
full_prueba = full

# %%
full_prueba.sample()
# Out:
#              Spot   date  time  range height_ft swell_dir  swell_angle  \
# 8833  Mosca Point  17/01  12pm  1-2ft       1.5       ESE          101
#
#      period_sec  wind_kmh wind_dir     wind  wind_angle temp_°c Conditions
# 8833          5        12      ESE  Onshore         109      16       Epic

# %%
full_prueba[['height','measurement']] = full_prueba.height.str.split("ft",expand=True,)

# %%
full_prueba[['period','measurement2']] = full_prueba.period.str.split("s",expand=True,)

# %%
full_prueba[['temp','measurement2']] = full_prueba.temp.str.split("°c",expand=True,)

# %%
full_prueba.rename(columns={"temp": "temp_°c"},inplace = True)

# %%
full_prueba.rename(columns={"period": "period_sec"},inplace = True)

# %%
full_prueba_2 = full_prueba

# %%
full_prueba_2.head()
# Out:
#      Spot   date  time   range height_ft swell_dir  swell_angle period_sec  \
# 0  Nazare  01/01   6am  7-11ft         5        NW          306         11
# 1  Nazare  01/01  12pm  7-11ft         5        NW          310         10
# 2  Nazare  01/01   6pm  6-10ft       4.5        NW          309         10
# 3  Nazare  02/01   6am   4-7ft       2.5        NW          322         10
# 4  Nazare  02/01  12pm   5-8ft         3         W          276         12
#
#    wind_kmh wind_dir      wind  wind_angle temp_°c Conditions
# 0         4      ESE  Offshore         115       6       Good
# 1         6       SE  Offshore         144      13       Good
# 2         1        S  Offshore         171       8       Good
# 3         6       SE  Offshore         129       6       Good
# 4         9      SSE  Offshore         156      11       Good

# %%
full_prueba_2 = full_prueba_2.astype({"height_ft": float, "swell_angle": int,"period_sec": int, "wind_kmh": int, "wind_angle":int,"temp_°c":int  })

# %%
full_prueba_2.dtypes
# Out:
# Spot            object
# date            object
# time            object
# range           object
# height_ft      float64
# swell_dir       object
# swell_angle      int64
# period_sec       int64
# wind_kmh         int64
# wind_dir        object
# wind            object
# wind_angle       int64
# temp_°c          int64
# Conditions      object
# dtype: object

# %%
full = full_prueba_2

# %%
full.head()
# Out:
#      Spot   date  time   range  height_ft swell_dir  swell_angle  period_sec  \
# 0  Nazare  01/01   6am  7-11ft        5.0        NW          306          11
# 1  Nazare  01/01  12pm  7-11ft        5.0        NW          310          10
# 2  Nazare  01/01   6pm  6-10ft        4.5        NW          309          10
# 3  Nazare  02/01   6am   4-7ft        2.5        NW          322          10
# 4  Nazare  02/01  12pm   5-8ft        3.0         W          276          12
#
#    wind_kmh wind_dir      wind  wind_angle  temp_°c Conditions
# 0         4      ESE  Offshore         115        6       Good
# 1         6       SE  Offshore         144       13       Good
# 2         1        S  Offshore         171        8       Good
# 3         6       SE  Offshore         129        6       Good
# 4         9      SSE  Offshore         156       11       Good

# %%
full.dtypes
# Out:
# Spot            object
# date            object
# time            object
# range           object
# height_ft      float64
# swell_dir       object
# swell_angle      int64
# period_sec       int64
# wind_kmh         int64
# wind_dir        object
# wind            object
# wind_angle       int64
# temp_°c          int64
# Conditions      object
# dtype: object

# %%
full.to_csv("Full_clean_df.csv", index=False)

# %% [markdown]
# ### Insert into SQL

# %%
import os
import dotenv
import sqlalchemy as alch
from getpass import getpass

# %%
#dotenv.load_dotenv()
password = getpass("Introduce tu pass de sql: ")
dbName="surfscanner"
connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"
engine = alch.create_engine(connectionData)
print("me conecté")
# Out:
# Introduce tu pass de sql: ········
# me conecté

# %%
for i, fila in full.iterrows():
    engine.execute(
        f"""
        INSERT INTO data (Spot,date,time,range,height_ft,swell_dir,swell_angle,period_sec,wind_kmh,wind_dir,wind,wind_angle,temp_°c,Conditions) 
        VALUES
        ("{fila['Spot']}","{fila['date']}","{fila['time']}","{fila['range']}","{fila['height_ft']}","{fila['swell_dir']}","{fila['swell_angle']}","{fila['period_sec']}","{fila['wind_kmh']}","{fila['wind_dir']}","{fila['wind']}","{fila['wind_angle']}","{fila['temp_°c']}","{fila['Conditions']}");
       """
    )
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1770                 if not evt_handled:
# -> 1771                     self.dialect.do_execute(
#    1772                         cursor, statement, parameters, context
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# ~/.local/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# ~/.local/lib/python3.8/site-packages/pymysql/cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# ~/.local/lib/python3.8/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#
# ~/.local/lib/python3.8/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#
# ~/.local/lib/python3.8/site-packages/pymysql/connections.py in read(self)
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#
# ~/.local/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# ~/.local/lib/python3.8/site-packages/pymysql/protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# ~/.local/lib/python3.8/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'range,height_ft,swell_dir,swell_angle,period_sec,wind_kmh,wind_dir,wind,wind_ang' at line 1")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# /tmp/ipykernel_157/3965836435.py in <module>
#       1 for i, fila in full.iterrows():
# ----> 2     engine.execute(
#       3         f"""
#       4         INSERT INTO data (Spot,date,time,range,height_ft,swell_dir,swell_angle,period_sec,wind_kmh,wind_dir,wind,wind_angle,temp_°c,Conditions)
#       5         VALUES
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    3106         """
#    3107         connection = self.connect(close_with_result=True)
# -> 3108         return connection.execute(statement, *multiparams, **params)
#    3109
#    3110     @util.deprecated_20(
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1246             )
#    1247
# -> 1248             return self._exec_driver_sql(
#    1249                 statement,
#    1250                 multiparams,
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1545
#    1546         dialect = self.dialect
# -> 1547         ret = self._execute_context(
#    1548             dialect,
#    1549             dialect.execution_ctx_cls._init_statement,
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1812
#    1813         except BaseException as e:
# -> 1814             self._handle_dbapi_exception(
#    1815                 e, statement, parameters, cursor, context
#    1816             )
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1993                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1994             elif should_wrap:
# -> 1995                 util.raise_(
#    1996                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1997                 )
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1769                             break
#    1770                 if not evt_handled:
# -> 1771                     self.dialect.do_execute(
#    1772                         cursor, statement, parameters, context
#    1773                     )
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#     719     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~/.local/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ~/.local/lib/python3.8/site-packages/pymysql/cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# ~/.local/lib/python3.8/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# ~/.local/lib/python3.8/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# ~/.local/lib/python3.8/site-packages/pymysql/connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# ~/.local/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# ~/.local/lib/python3.8/site-packages/pymysql/protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# ~/.local/lib/python3.8/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'range,height_ft,swell_dir,swell_angle,period_sec,wind_kmh,wind_dir,wind,wind_ang' at line 1")
# [SQL:
#         INSERT INTO data (Spot,date,time,range,height_ft,swell_dir,swell_angle,period_sec,wind_kmh,wind_dir,wind,wind_angle,temp_°c,Conditions)
#         VALUES
#         ("Nazare","01/01","6am","7-11ft","5.0","NW","306","11","4","ESE","Offshore","115","6","Good");
#        ]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
full.shape
# Out:
# (8784, 15)
