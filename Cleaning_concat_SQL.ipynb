# %%
import pandas as pd

# %%
nazare = pd.read_csv (r'firstdf.csv')
pipeline = pd.read_csv (r'pipedf.csv')
mundaka = pd.read_csv (r'mundaka.csv')
fronton = pd.read_csv (r'fronton.csv')
box = pd.read_csv (r'firstdf.csv')
puerto_escondido = pd.read_csv (r'puerto_escondido.csv')
itacoatiara = pd.read_csv (r'itacoatiara.csv')
padang_padang = pd.read_csv (r'padang-padang.csv')
kirra = pd.read_csv (r'kirra.csv')

# %% [markdown]
# ### Cleaning Mundaka

# %%
mundaka.drop(["x1","x2","x3","x4"], axis=1, inplace= True)

# %%
mundaka.head()
# Out:
#     date  time  range height period wind_mph wind_kmh  mph  temp  prob  \
# 0  01/01   6am  3-4ft    4ft    12s        6        6  mph  10°c  100%
# 1  01/01  12pm  3-4ft  4.5ft    11s        6        6  mph  11°c  100%
# 2  01/01   6pm  3-4ft  4.5ft    11s        6        6  mph  12°c  100%
# 3  02/01   6am  2-3ft    3ft    10s        7        8  mph  10°c  100%
# 4  02/01  12pm  2-3ft  2.5ft    10s        8        9  mph  11°c  100%
#
#   swell_dir swell_angle      wind wind_dir wind_angle
# 0       WNW         304  Offshore       SW        220
# 1        NW         305  Offshore      SSW        194
# 2        NW         307   Onshore        E         91
# 3        NW         311  Offshore      SSE        149
# 4        NW         312  Offshore        S        183

# %%
mundaka.to_csv("mundaka_clean.csv", index=False)

# %%
nazare_ = ["Nazare"]
pipeline_ = ["Pipeline"]
mundaka_ = ["Mundaka"]
fronton_ = ["Fronton"]
box_ = ["Box"]
puerto_escondido_ = ["Puerto Escondido"]
itacoatiara_ =  ["Itacoatiara"]
padang_padang_ =  ["Padang-Padang"]
kirra_ = ["Kirra"]

# %%
list_nazare = nazare_ * nazare.shape[0]

# %%
list_pipeline = pipeline_ * nazare.shape[0]

# %%
list_mundaka = mundaka_ * nazare.shape[0]

# %%
list_fronton = fronton_ * nazare.shape[0]

# %%
list_box = box_ * nazare.shape[0]

# %%
list_puerto_escondido = puerto_escondido_ * nazare.shape[0]

# %%
list_itacoatiara = itacoatiara_ * nazare.shape[0]

# %%
list_padang_padang = padang_padang_ * nazare.shape[0]

# %%
list_kirra = kirra_ * nazare.shape[0]

# %% [markdown]
# ### Inserting new columns (quality,name)

# %%
nazare.shape
# Out:
# (1098, 15)

# %%
nazare.head()
# Out:
#     date  time   range height period  wind_mph  wind_kmh  mph  temp  prob  \
# 0  01/01   6am  7-11ft    5ft    11s         3         4  mph   6°c  100%
# 1  01/01  12pm  7-11ft    5ft    10s         4         6  mph  13°c  100%
# 2  01/01   6pm  6-10ft  4.5ft    10s         1         1  mph   8°c  100%
# 3  02/01   6am   4-7ft  2.5ft    10s         5         6  mph   6°c  100%
# 4  02/01  12pm   5-8ft    3ft    12s         6         9  mph  11°c  100%
#
#   swell_dir  swell_angle      wind wind_dir  wind_angle    Spot
# 0        NW          306  Offshore      ESE         115  Nazare
# 1        NW          310  Offshore       SE         144  Nazare
# 2        NW          309  Offshore        S         171  Nazare
# 3        NW          322  Offshore       SE         129  Nazare
# 4         W          276  Offshore      SSE         156  Nazare

# %%
nazare['Spot'] = list_nazare

# %%
full = pd.concat([nazare ,pipeline ,mundaka , fronton ,box,puerto_escondido ,itacoatiara ,padang_padang], ignore_index=True)

# %%
full
# Out:
#        date  time   range height period wind_mph wind_kmh  mph  temp  prob  \
# 0     01/01   6am  7-11ft    5ft    11s        3        4  mph   6°c  100%
# 1     01/01  12pm  7-11ft    5ft    10s        4        6  mph  13°c  100%
# 2     01/01   6pm  6-10ft  4.5ft    10s        1        1  mph   8°c  100%
# 3     02/01   6am   4-7ft  2.5ft    10s        5        6  mph   6°c  100%
# 4     02/01  12pm   5-8ft    3ft    12s        6        9  mph  11°c  100%
# ...     ...   ...     ...    ...    ...      ...      ...  ...   ...   ...
# 8779  30/12  12pm   3-5ft    4ft    10s       10       11  mph  28°c   NaN
# 8780  30/12   6pm   4-6ft  4.5ft    11s        8        8  mph  28°c   NaN
# 8781  31/12   6am   4-7ft    4ft    19s        2        4  mph  28°c   NaN
# 8782  31/12  12pm   4-6ft  3.5ft    18s        6        7  mph  28°c   NaN
# 8783  31/12   6pm   5-8ft  4.5ft    18s        7        7  mph  28°c   NaN
#
#      swell_dir swell_angle      wind wind_dir wind_angle
# ...
